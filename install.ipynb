# %%
pip install mediapipe
# Out:
# ...
#    ---------------------------------------- 0.0/50.8 MB ? eta -:--:--
#    ---------------------------------------- 0.2/50.8 MB 6.3 MB/s eta 0:00:09
#    ---------------------------------------- 0.5/50.8 MB 6.3 MB/s eta 0:00:08
#     --------------------------------------- 0.8/50.8 MB 6.5 MB/s eta 0:00:08
#     --------------------------------------- 1.1/50.8 MB 6.5 MB/s eta 0:00:08
#    - -------------------------------------- 1.5/50.8 MB 6.6 MB/s eta 0:00:08
#    - -------------------------------------- 1.7/50.8 MB 6.5 MB/s eta 0:00:08
#    - -------------------------------------- 2.0/50.8 MB 6.5 MB/s eta 0:00:08
#    - -------------------------------------- 2.3/50.8 MB 6.3 MB/s eta 0:00:08
#    -- ------------------------------------- 2.6/50.8 MB 6.5 MB/s eta 0:00:08
#    -- ------------------------------------- 3.0/50.8 MB 6.7 MB/s eta 0:00:08
#    -- ------------------------------------- 3.8/50.8 MB 7.5 MB/s eta 0:00:07
# ...

# %%
pip install opencv-contrib-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.10.0
